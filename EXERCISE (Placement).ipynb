# %%
import numpy as np
import pandas as pd

# %%
pla = pd.read_csv('Placement_Data.csv')

# %%
pla.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
pla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
pla.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
pla['salary'].fillna(pla['salary'].mean(),inplace=True)

# %%
pla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          215 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
#1
pla[pla['gender']=='M'].nlargest(5,'salary',keep='all')
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 119    120      M  60.80  Central  68.40  Central  Commerce     64.60
# 150    151      M  71.00  Central  58.66  Central   Science     58.00
# 77      78      M  64.00   Others  80.00   Others   Science     65.00
# 163    164      M  63.00   Others  67.00   Others   Science     64.00
# 174    175      M  73.24   Others  50.83   Others   Science     64.27
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 119  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 150   Sci&Tech    Yes    56.00        Mkt&Fin  61.30  Placed  690000.0
# 77    Sci&Tech    Yes    69.00        Mkt&Fin  57.65  Placed  500000.0
# 163   Sci&Tech     No    75.00        Mkt&Fin  66.46  Placed  500000.0
# 174   Sci&Tech    Yes    64.00        Mkt&Fin  66.23  Placed  500000.0

# %%
#2
pla[pla['gender']=='M'].nsmallest(5,'salary',keep='all')
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 107    108      M  82.00   Others  90.00   Others  Commerce     83.00
# 47      48      M  63.00  Central  60.00  Central  Commerce     57.00
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 73      74      M  64.60  Central  83.83   Others  Commerce     71.72
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28  Placed  200000.0
# 107  Comm&Mgmt     No     80.0         Mkt&HR  73.52  Placed  200000.0
# 47   Comm&Mgmt    Yes     78.0        Mkt&Fin  54.55  Placed  204000.0
# 209  Comm&Mgmt     No     67.0        Mkt&Fin  56.49  Placed  216000.0
# 73   Comm&Mgmt     No     86.0        Mkt&Fin  59.75  Placed  218000.0

# %%
#3
pla[pla['gender']=='F'].nlargest(15,'salary',keep='all')
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 177    178      F  73.00  Central  97.00   Others  Commerce     79.00
# 85      86      F  83.84   Others  89.83   Others  Commerce     77.20
# 21      22      F  79.00   Others  76.00   Others  Commerce     85.00
# 22      23      F  69.80   Others  60.80   Others   Science     72.23
# 131    132      F  74.90   Others  57.00   Others   Science     62.00
# 125    126      F  84.00  Central  73.00  Central  Commerce     73.00
# 37      38      F  79.00  Central  76.00  Central   Science     65.60
# 23      24      F  77.40   Others  60.00   Others   Science     64.74
# 35      36      F  69.00  Central  78.00  Central  Commerce     72.00
# 90      91      F  85.00   Others  90.00   Others  Commerce     82.00
# 96      97      F  76.00  Central  70.00  Central   Science     76.00
# 102    103      F  77.00   Others  61.00   Others  Commerce     68.00
# ...

# %%
#4
pla[pla['gender']=='F'].nsmallest(10,'salary',keep='all')
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 15      16      F   65.0  Central   75.0  Central  Commerce      69.0
# 44      45      F   77.0   Others   73.0   Others  Commerce      81.0
# 50      51      F   75.2  Central   73.2  Central   Science      68.4
# 135    136      F   72.0  Central   56.0   Others   Science      69.0
# 213    214      F   74.0   Others   66.0   Others  Commerce      58.0
# 88      89      F   66.0  Central   62.0  Central  Commerce      73.0
# 89      90      F   84.0   Others   75.0   Others   Science      69.0
# 126    127      F   79.0   Others   61.0   Others   Science      75.5
# 204    205      F   74.0   Others   73.0   Others  Commerce      73.0
# 54      55      F   74.0  Central   60.0   Others   Science      69.0
# 115    116      F   73.0   Others   63.0   Others   Science      66.0
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
#5
pla[(pla['hsc_s']=='Commerce') & (pla['gender']=='F')].nlargest(15,'salary',keep='all')
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 177    178      F  73.00  Central  97.00   Others  Commerce     79.00
# 85      86      F  83.84   Others  89.83   Others  Commerce     77.20
# 21      22      F  79.00   Others  76.00   Others  Commerce     85.00
# 125    126      F  84.00  Central  73.00  Central  Commerce     73.00
# 35      36      F  69.00  Central  78.00  Central  Commerce     72.00
# 90      91      F  85.00   Others  90.00   Others  Commerce     82.00
# 102    103      F  77.00   Others  61.00   Others  Commerce     68.00
# 6        7      F  46.00   Others  49.20   Others  Commerce     79.00
# 17      18      F  55.00  Central  67.00  Central  Commerce     64.00
# 18      19      F  63.00  Central  66.00  Central  Commerce     64.00
# 25      26      F  52.58   Others  54.60  Central  Commerce     50.20
# 41      42      F  74.00   Others  63.16   Others  Commerce     65.00
# ...

# %%
#6
pla[(pla['hsc_s']=='Arts') & (pla['gender']=='F')].nlargest(10,'salary',keep='all')
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b hsc_s  degree_p   degree_t  \
# 193    194      F   60.0  Central   63.0  Central  Arts     56.00     Others
# 49      50      F   50.0   Others   37.0   Others  Arts     52.00     Others
# 136    137      F   47.0  Central   59.0  Central  Arts     64.00  Comm&Mgmt
# 148    149      F   77.0  Central   86.0  Central  Arts     56.00     Others
# 122    123      F   66.5  Central   66.8  Central  Arts     69.30  Comm&Mgmt
# 76      77      F   66.5   Others   70.4  Central  Arts     71.93  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status         salary
# 193    Yes     80.0         Mkt&HR  56.63      Placed  300000.000000
# 49      No     65.0         Mkt&HR  56.11  Not Placed  288655.405405
# 136     No     78.0        Mkt&Fin  61.58  Not Placed  288655.405405
# 148     No     57.0        Mkt&Fin  64.08      Placed  240000.000000
# 122    Yes     80.4        Mkt&Fin  71.00      Placed  236000.000000
# ...

# %%
#7
pla[(pla['hsc_s']=='Commerce') & (pla['gender']=='M')].nsmallest(10,'salary',keep='all')
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 107    108      M   82.0   Others  90.00   Others  Commerce     83.00
# 47      48      M   63.0  Central  60.00  Central  Commerce     57.00
# 209    210      M   62.0  Central  72.00  Central  Commerce     65.00
# 73      74      M   64.6  Central  83.83   Others  Commerce     71.72
# 86      87      M   62.0   Others  63.00   Others  Commerce     64.00
# 139    140      M   77.0  Central  70.00  Central  Commerce     59.00
# 137    138      M   67.0   Others  63.00  Central  Commerce     72.00
# 8        9      M   73.0  Central  79.00  Central  Commerce     72.00
# 26      27      M   71.0   Others  79.00   Others  Commerce     66.00
# 56      57      M   63.0   Others  71.40   Others  Commerce     61.40
# 64      65      M   80.0   Others  73.00   Others  Commerce     75.00
# 71      72      M   75.0   Others  70.29   Others  Commerce     71.00
# ...

# %%
#8
pla[(pla['degree_t']=='Sci&Tech') & (pla['hsc_s']=='Commerce')].nsmallest(5,'salary',keep='all')
# Out:
#     sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0       1      M   67.0   Others   91.0   Others  Commerce      58.0
# 68     69      F   69.7  Central   47.0  Central  Commerce      72.7
# 99    100      M   54.0  Central   82.0   Others  Commerce      63.0
#
#     degree_t workex  etest_p specialisation  mba_p      status         salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.000000
# 68  Sci&Tech     No     79.0         Mkt&HR  59.24  Not Placed  288655.405405
# 99  Sci&Tech     No     50.0        Mkt&Fin  59.47  Not Placed  288655.405405

# %%
#9
pla[(pla['degree_t']=='Sci&Tech') & (pla['hsc_s']=='Commerce') & (pla['workex']=='No')].nlargest(1,'salary',keep='all')
# Out:
#     sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 68     69      F   69.7  Central   47.0  Central  Commerce      72.7
# 99    100      M   54.0  Central   82.0   Others  Commerce      63.0
#
#     degree_t workex  etest_p specialisation  mba_p      status         salary
# 68  Sci&Tech     No     79.0         Mkt&HR  59.24  Not Placed  288655.405405
# 99  Sci&Tech     No     50.0        Mkt&Fin  59.47  Not Placed  288655.405405

# %%
#10
pla[(pla['degree_t']=='Comm&Mgmt') & (pla['workex']=='Yes') & (pla['hsc_s']=='Science')].nsmallest(1,'salary',keep='all')
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p   hsc_b    hsc_s  degree_p  \
# 154    155      M   53.0  Central   63.0  Others  Science      60.0
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 154  Comm&Mgmt    Yes     70.0        Mkt&Fin   53.2  Placed  250000.0

# %%
#11
pla[(pla['gender']=='F') & (pla['specialisation']=='Mkt&HR') & (pla['workex']=='Yes')]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 41      42      F   74.0   Others  63.16   Others  Commerce      65.0
# 80      81      F   69.0   Others  62.00   Others  Commerce      69.0
# 89      90      F   84.0   Others  75.00   Others   Science      69.0
# 100    101      F   45.0   Others  57.00   Others  Commerce      58.0
# 121    122      F   64.0  Central  67.00   Others   Science      69.6
# 168    169      F   48.0  Central  51.00  Central  Commerce      58.0
# 193    194      F   60.0  Central  63.00  Central      Arts      56.0
#
#       degree_t workex  etest_p specialisation  mba_p      status  \
# 41   Comm&Mgmt    Yes    65.00         Mkt&HR  69.76  Not Placed
# 80   Comm&Mgmt    Yes    67.00         Mkt&HR  62.35      Placed
# 89    Sci&Tech    Yes    62.00         Mkt&HR  62.36      Placed
# 100  Comm&Mgmt    Yes    56.39         Mkt&HR  64.95  Not Placed
# 121   Sci&Tech    Yes    55.67         Mkt&HR  71.49      Placed
# ...

# %%
#12
pla[pla['workex']=='No'].nlargest(1,'salary',keep='all')
# Out:
#      sl_no gender  ssc_p   ssc_b  hsc_p   hsc_b    hsc_s  degree_p  degree_t  \
# 163    164      M   63.0  Others   67.0  Others  Science      64.0  Sci&Tech
#
#     workex  etest_p specialisation  mba_p  status    salary
# 163     No     75.0        Mkt&Fin  66.46  Placed  500000.0

# %%
#13
pla[pla['workex']=='Yes'].nlargest(1,'salary',keep='all')
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 119    120      M   60.8  Central   68.4  Central  Commerce      64.6
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 119  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0

# %%
#14
pla[(pla['workex']=='No') & (pla['degree_t']=='Sci&Tech')].nsmallest(1,'salary','all')
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b    hsc_s  degree_p  \
# 62      63      F   86.5   Others   64.2   Others  Science      67.4
# 117    118      M   77.0   Others   75.0   Others  Science      73.0
# 152    153      F   75.4   Others   60.5  Central  Science      84.0
# 202    203      M   70.0  Central   63.0  Central  Science      66.0
#
#      degree_t workex  etest_p specialisation  mba_p  status    salary
# 62   Sci&Tech     No    59.00        Mkt&Fin  59.69  Placed  240000.0
# 117  Sci&Tech     No    80.00        Mkt&Fin  67.05  Placed  240000.0
# 152  Sci&Tech     No    98.00        Mkt&Fin  65.25  Placed  240000.0
# 202  Sci&Tech     No    61.28         Mkt&HR  60.11  Placed  240000.0

# %%
#15
pla[(pla['workex']=='No') & (pla['ssc_p']>66)].nlargest(1,'salary',keep='all')
# Out:
#     sl_no gender  ssc_p   ssc_b  hsc_p   hsc_b    hsc_s  degree_p  degree_t  \
# 53     54      M   80.0  Others   70.0  Others  Science      72.0  Sci&Tech
#
#    workex  etest_p specialisation  mba_p  status    salary
# 53     No     87.0         Mkt&HR  71.04  Placed  450000.0

# %%
#16
pla.loc[pla['salary']>pla['salary'].mean(),'salary']= pla['salary'].mean()

# %%
#17
pla.loc[pla['ssc_p']>pla['ssc_p'].mean(),'ssc_p'] = pla['ssc_p'].mean()

# %%
#18
pla.loc[pla['hsc_p']>pla['hsc_p'].mean(),'hsc_p'] = pla['hsc_p'].mean()

# %%
#19
pla.loc[pla['degree_p']>pla['degree_p'].mean(),'degree_p'] = pla['degree_p'].mean()

# %%
#20
pla.loc[pla['etest_p']>pla['etest_p'].mean(),'etest_p'] = pla['etest_p'].mean()

# %%
#21
pla.loc[pla['specialisation']=='Mkt&HR','specialisation'] = 'HR'

# %%
#22
pla.loc[pla['ssc_b']=='Others','ssc_b'] = 'PYTHON'

# %%
#23
pla.loc[pla['degree_t']=='Sci&Tech','degree_t'] = 'Sci&Com'

# %% [markdown]
# # Done!
