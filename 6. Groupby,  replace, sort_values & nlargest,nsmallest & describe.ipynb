# %%
import pandas as pd
import numpy as np
# Create dataframe
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,124,340,243,350]}
df=pd.DataFrame(data)
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    124
# 3    MSFT  Vanessa    340
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
car = pd.read_csv('Car_sales.csv')
ufo = pd.read_csv('Ufo.csv')
car.head(20)
# Out:
#      Manufacturer              Model  Sales in thousands  x_4_year  \
# 0   Acura          Integra                        16.919    16.360
# 1   Acura          TL                             39.384    19.875
# 2   Acura          CL                             14.114    18.225
# 3   Acura          RL                              8.588    29.725
# 4   Audi           A4                             20.397    22.255
# 5   Audi           A6                             18.780    23.555
# 6   Audi           A8                              1.380    39.000
# 7             NaN  323i                           19.747       NaN
# 8             NaN  328i                            9.231    28.675
# 9             NaN  528i                           17.527    36.125
# 10  Buick          Century                        91.561    12.475
# 11  Buick          Regal                          39.350    13.740
# 12  Buick          Park Avenue                    27.851    20.190
# ...

# %%
car['Manufacturer'].replace(np.nan,'BMW',inplace=True,regex=True)

# %%
car
# Out:
#       Manufacturer              Model  Sales in thousands  x_4_year  \
# 0    Acura          Integra                        16.919    16.360
# 1    Acura          TL                             39.384    19.875
# 2    Acura          CL                             14.114    18.225
# 3    Acura          RL                              8.588    29.725
# 4    Audi           A4                             20.397    22.255
# ..             ...                ...                 ...       ...
# 152  Volvo          V40                             3.545       NaN
# 153  Volvo          S70                            15.245       NaN
# 154  Volvo          V70                            17.531       NaN
# 155  Volvo          C70                             3.493       NaN
# 156  Volvo          S80                            18.969       NaN
#
#     Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
car[car['Manufacturer']=='BMW'].shape
# Out:
# (3, 17)

# %%
car[car['Manufacturer']=='BMW']
# Out:
#   Manufacturer              Model  Sales in thousands  x_4_year Vehicle type  \
# 7          BMW  323i                           19.747       NaN    Passenger
# 8          BMW  328i                            9.231    28.675    Passenger
# 9          BMW  528i                           17.527    36.125    Passenger
#
#    Price in thousands  Engine size  Horsepower  Wheelbase  Width  Length  \
# 7               26.99          2.5       170.0      107.3   68.4   176.0
# 8               33.40          2.8       193.0      107.3   68.5   176.0
# 9               38.90          2.8       193.0      111.4   70.9   188.0
#
#    Curb weight  Fuel capacity  Fuel efficiency Latest Launch  Unnamed: 15  \
# 7        3.179           16.6             26.0     28-Jun-15          NaN
# 8        3.197           16.6             24.0     29-Jan-14          NaN
# 9        3.472           18.5             25.0      4-Apr-15          NaN
#
#        XX
# 7     NaN
# 8  28.675
# 9  36.125

# %%
car['Manufacturer'].values
# Out:
# array(['Acura        ', 'Acura        ', 'Acura        ', 'Acura        ',
#        'Audi         ', 'Audi         ', 'Audi         ', 'BMW', 'BMW',
#        'BMW', 'Buick        ', 'Buick        ', 'Buick        ',
#        'Buick        ', 'Cadillac     ', 'Cadillac     ', 'Cadillac     ',
#        'Cadillac     ', 'Cadillac     ', 'Chevrolet    ', 'Chevrolet    ',
#        'Chevrolet    ', 'Chevrolet    ', 'Chevrolet    ', 'Chevrolet    ',
#        'Chevrolet    ', 'Chevrolet    ', 'Chevrolet    ', 'Chrysler     ',
#        'Chrysler     ', 'Chrysler     ', 'Chrysler     ', 'Chrysler     ',
#        'Chrysler     ', 'Chrysler     ', 'Dodge        ', 'Dodge        ',
#        'Dodge        ', 'Dodge        ', 'Dodge        ', 'Dodge        ',
#        'Dodge        ', 'Dodge        ', 'Dodge        ', 'Dodge        ',
#        'Dodge        ', 'Ford         ', 'Ford         ', 'Ford         ',
#        'Ford         ', 'Ford         ', 'Ford         ', 'Ford         ',
# ...

# %%
car.replace(['Ford','Audi','Buick'],['Nissan','Ambassador','Santro'],regex=True)
# Out:
#             Manufacturer              Model  Sales in thousands  x_4_year  \
# 0          Acura          Integra                        16.919    16.360
# 1          Acura          TL                             39.384    19.875
# 2          Acura          CL                             14.114    18.225
# 3          Acura          RL                              8.588    29.725
# 4    Ambassador           A4                             20.397    22.255
# ..                   ...                ...                 ...       ...
# 152        Volvo          V40                             3.545       NaN
# 153        Volvo          S70                            15.245       NaN
# 154        Volvo          V70                            17.531       NaN
# 155        Volvo          C70                             3.493       NaN
# 156        Volvo          S80                            18.969       NaN
#
#     Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  \
# ...

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    124
# 3    MSFT  Vanessa    340
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
df.groupby('Company').sum()
# Out:
#          Sales
# Company
# FB         593
# GOOG       320
# MSFT       464

# %%
df.groupby('Company').max()
# Out:
#           Person  Sales
# Company
# FB         Sarah    350
# GOOG         Sam    200
# MSFT     Vanessa    340

# %%
df.groupby('Company').min()
# Out:
#           Person  Sales
# Company
# FB          Carl    243
# GOOG     Charlie    120
# MSFT         Amy    124

# %%
df.groupby('Company').mean()
# Out:
#          Sales
# Company
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %%
car.head()
# Out:
#     Manufacturer              Model  Sales in thousands  x_4_year  \
# 0  Acura          Integra                        16.919    16.360
# 1  Acura          TL                             39.384    19.875
# 2  Acura          CL                             14.114    18.225
# 3  Acura          RL                              8.588    29.725
# 4  Audi           A4                             20.397    22.255
#
#   Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb weight  Fuel capacity  Fuel efficiency Latest Launch  \
# ...

# %%
car.groupby('Manufacturer').mean()[['Sales in thousands','Price in thousands','Fuel efficiency']]
# Out:
#                Sales in thousands  Price in thousands  Fuel efficiency
# Manufacturer
# Acura                   19.751250           30.633333        25.250000
# Audi                    13.519000           39.980000        23.333333
# BMW                     15.501667           33.096667        25.000000
# Buick                   60.504750           26.781250        24.250000
# Cadillac                22.435600           40.254000        20.600000
# Chevrolet               61.596111           20.022778        28.444444
# Chrysler                28.817286           23.430833        24.500000
# Dodge                   82.740818           24.213636        20.100000
# Ford                   183.875909           21.047273        22.818182
# Honda                  118.534800           20.277000        25.000000
# Hyundai                 45.775333           12.165667        27.666667
# Infiniti                23.713000           29.465000        25.000000
# ...

# %%
car.groupby('Manufacturer').max()
# Out:
#                            Model  Sales in thousands  x_4_year Vehicle type  \
# Manufacturer
# Acura          TL                             39.384    29.725    Passenger
# Audi           A8                             20.397    39.000    Passenger
# BMW            528i                           19.747    36.125    Passenger
# Buick          Regal                          91.561    20.190    Passenger
# Cadillac       Seville                        63.729    27.100    Passenger
# Chevrolet      Prizm                         145.519    36.225    Passenger
# Chrysler       Town & Country                 53.480    19.540    Passenger
# Dodge          Viper                         227.061    58.470    Passenger
# Ford           Windstar                      540.561    23.575    Passenger
# Honda          Passport                      230.902    19.490    Passenger
# Hyundai        Sonata                         66.692     8.910    Passenger
# ...

# %%
print(df.groupby("Company").mean())
print(df.groupby("Company").sum())
print(df.groupby("Company").var())
print(df.groupby("Company").std())
print(df.groupby("Company").min())
print(df.groupby("Company").max())
print(df.groupby("Company").median())
# Out:
#          Sales
# Company
# FB       296.5
# GOOG     160.0
# MSFT     232.0
#          Sales
# Company
# FB         593
# GOOG       320
# MSFT       464
#            Sales
# Company
# FB        5724.5
# GOOG      3200.0
# MSFT     23328.0
#               Sales
# Company
# FB        75.660426
# GOOG      56.568542
# MSFT     152.735065
#           Person  Sales
# Company
# FB          Carl    243
# GOOG     Charlie    120
# MSFT         Amy    124
#           Person  Sales
# Company
# FB         Sarah    350
# GOOG         Sam    200
# MSFT     Vanessa    340
#          Sales
# Company
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %%
car['Manufacturer']
# Out:
# 0      Acura
# 1      Acura
# 2      Acura
# 3      Acura
# 4      Audi
#            ...
# 152    Volvo
# 153    Volvo
# 154    Volvo
# 155    Volvo
# 156    Volvo
# Name: Manufacturer, Length: 157, dtype: object

# %%
car[car['Manufacturer']=='Acura']
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model, Sales in thousands, x_4_year, Vehicle type, Price in thousands, Engine size, Horsepower, Wheelbase, Width, Length, Curb weight, Fuel capacity, Fuel efficiency, Latest Launch, Unnamed: 15, XX]
# Index: []

# %%
car['Manufacturer'].values
# Out:
# array(['Acura        ', 'Acura        ', 'Acura        ', 'Acura        ',
#        'Audi         ', 'Audi         ', 'Audi         ', 'BMW', 'BMW',
#        'BMW', 'Buick        ', 'Buick        ', 'Buick        ',
#        'Buick        ', 'Cadillac     ', 'Cadillac     ', 'Cadillac     ',
#        'Cadillac     ', 'Cadillac     ', 'Chevrolet    ', 'Chevrolet    ',
#        'Chevrolet    ', 'Chevrolet    ', 'Chevrolet    ', 'Chevrolet    ',
#        'Chevrolet    ', 'Chevrolet    ', 'Chevrolet    ', 'Chrysler     ',
#        'Chrysler     ', 'Chrysler     ', 'Chrysler     ', 'Chrysler     ',
#        'Chrysler     ', 'Chrysler     ', 'Dodge        ', 'Dodge        ',
#        'Dodge        ', 'Dodge        ', 'Dodge        ', 'Dodge        ',
#        'Dodge        ', 'Dodge        ', 'Dodge        ', 'Dodge        ',
#        'Dodge        ', 'Ford         ', 'Ford         ', 'Ford         ',
#        'Ford         ', 'Ford         ', 'Ford         ', 'Ford         ',
# ...

# %%
car['Manufacturer']=car['Manufacturer'].str.strip()
car['Manufacturer'].values
# Out:
# array(['Acura', 'Acura', 'Acura', 'Acura', 'Audi', 'Audi', 'Audi', 'BMW',
#        'BMW', 'BMW', 'Buick', 'Buick', 'Buick', 'Buick', 'Cadillac',
#        'Cadillac', 'Cadillac', 'Cadillac', 'Cadillac', 'Chevrolet',
#        'Chevrolet', 'Chevrolet', 'Chevrolet', 'Chevrolet', 'Chevrolet',
#        'Chevrolet', 'Chevrolet', 'Chevrolet', 'Chrysler', 'Chrysler',
#        'Chrysler', 'Chrysler', 'Chrysler', 'Chrysler', 'Chrysler',
#        'Dodge', 'Dodge', 'Dodge', 'Dodge', 'Dodge', 'Dodge', 'Dodge',
#        'Dodge', 'Dodge', 'Dodge', 'Dodge', 'Ford', 'Ford', 'Ford', 'Ford',
#        'Ford', 'Ford', 'Ford', 'Ford', 'Ford', 'Ford', 'Ford', 'Honda',
#        'Honda', 'Honda', 'Honda', 'Honda', 'Hyundai', 'Hyundai',
#        'Hyundai', 'Infiniti', 'Jaguar', 'Jeep', 'Jeep', 'Jeep', 'Lexus',
#        'Lexus', 'Lexus', 'Lexus', 'Lexus', 'Lexus', 'Lincoln', 'Lincoln',
#        'Lincoln', 'Mitsubishi', 'Mitsubishi', 'Mitsubishi', 'Mitsubishi',
# ...

# %%
car['Manufacturer'].value_counts()
# Out:
# Dodge            11
# Ford             11
# Mercedes-Benz     9
# Chevrolet         9
# Toyota            9
# Chrysler          7
# Nissan            7
# Mitsubishi        7
# Oldsmobile        6
# Volkswagen        6
# Pontiac           6
# Volvo             6
# Mercury           6
# Lexus             6
# Cadillac          5
# Saturn            5
# Honda             5
# Plymouth          4
# Buick             4
# Acura             4
# Hyundai           3
# Lincoln           3
# Jeep              3
# BMW               3
# Porsche           3
# Audi              3
# Subaru            2
# Saab              2
# Jaguar            1
# Infiniti          1
# Name: Manufacturer, dtype: int64

# %%
car[car['Manufacturer']=='Acura']
# Out:
#   Manufacturer              Model  Sales in thousands  x_4_year Vehicle type  \
# 0        Acura  Integra                        16.919    16.360    Passenger
# 1        Acura  TL                             39.384    19.875    Passenger
# 2        Acura  CL                             14.114    18.225    Passenger
# 3        Acura  RL                              8.588    29.725    Passenger
#
#    Price in thousands  Engine size  Horsepower  Wheelbase  Width  Length  \
# 0                21.5          1.8       140.0      101.2   67.3   172.4
# 1                28.4          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3                42.0          3.5       210.0      114.6   71.4   196.6
#
#    Curb weight  Fuel capacity  Fuel efficiency Latest Launch  Unnamed: 15  \
# 0        2.639           13.2             28.0      2-Feb-14          NaN
# ...

# %%
car.groupby('Manufacturer').sum().sort_values('Price in thousands',ascending=True).head(10)[['Sales in thousands','Price in thousands']]
# Out:
#               Sales in thousands  Price in thousands
# Manufacturer
# Infiniti                  23.713              29.465
# Hyundai                  137.326              36.497
# Subaru                    80.135              42.790
# Jaguar                    15.467              42.800
# Saab                      21.306              59.220
# Jeep                     293.153              62.975
# Saturn                   168.850              71.355
# Plymouth                  64.001              90.570
# Acura                     79.005              91.900
# BMW                       46.505              99.290

# %%
car.groupby("Manufacturer").head(10)[["Manufacturer","Sales in thousands","Price in thousands"]].sort_values("Sales in thousands",ascending=False)
# Out:
#       Manufacturer  Sales in thousands  Price in thousands
# 52            Ford             276.747              31.930
# 137         Toyota             247.994              17.518
# 49            Ford             245.815              17.885
# 58           Honda             230.902              15.350
# 40           Dodge             227.061              19.460
# ..             ...                 ...                 ...
# 125        Porsche               1.280              71.020
# 108     Oldsmobile               1.112              18.145
# 99   Mercedes-Benz               0.954              85.500
# 39           Dodge               0.916              69.725
# 83      Mitsubishi               0.110              25.450
#
# [155 rows x 3 columns]

# %%
car.groupby("Manufacturer").head(10)
# Out:
#     Manufacturer              Model  Sales in thousands  x_4_year  \
# 0          Acura  Integra                        16.919    16.360
# 1          Acura  TL                             39.384    19.875
# 2          Acura  CL                             14.114    18.225
# 3          Acura  RL                              8.588    29.725
# 4           Audi  A4                             20.397    22.255
# ..           ...                ...                 ...       ...
# 152        Volvo  V40                             3.545       NaN
# 153        Volvo  S70                            15.245       NaN
# 154        Volvo  V70                            17.531       NaN
# 155        Volvo  C70                             3.493       NaN
# 156        Volvo  S80                            18.969       NaN
#
#     Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
car
# Out:
#     Manufacturer              Model  Sales in thousands  x_4_year  \
# 0          Acura  Integra                        16.919    16.360
# 1          Acura  TL                             39.384    19.875
# 2          Acura  CL                             14.114    18.225
# 3          Acura  RL                              8.588    29.725
# 4           Audi  A4                             20.397    22.255
# ..           ...                ...                 ...       ...
# 152        Volvo  V40                             3.545       NaN
# 153        Volvo  S70                            15.245       NaN
# 154        Volvo  V70                            17.531       NaN
# 155        Volvo  C70                             3.493       NaN
# 156        Volvo  S80                            18.969       NaN
#
#     Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
car.groupby('Manufacturer').max()[['Model','Sales in thousands','Price in thousands','Engine size']].sort_values('Sales in thousands',ascending=True).head(10)
# Out:
#                            Model  Sales in thousands  Price in thousands  \
# Manufacturer
# Porsche        Carrera Coupe                   8.982              74.970
# Saab                       5-Sep              12.115              33.120
# Jaguar         S-Type                         15.467              42.800
# Volvo          V70                            18.969              45.500
# BMW            528i                           19.747              38.900
# Audi           A8                             20.397              62.000
# Infiniti       I30                            23.713              29.465
# Mercedes-Benz  SLK230                         28.976              85.500
# Plymouth       Voyager                        32.734              43.000
# Acura          TL                             39.384              42.000
#
#                Engine size
# Manufacturer
# Porsche                3.4
# Saab                   2.3
# Jaguar                 3.0
# ...

# %%
car.sort_values("Sales in thousands",ascending=False)[["Manufacturer","Sales in thousands"]].head(10)
# Out:
#     Manufacturer  Sales in thousands
# 56          Ford             540.561
# 52          Ford             276.747
# 137       Toyota             247.994
# 49          Ford             245.815
# 58         Honda             230.902
# 40         Dodge             227.061
# 55          Ford             220.650
# 57         Honda             199.685
# 45         Dodge             181.749
# 50          Ford             175.670

# %%
car.groupby("Manufacturer").max()[["Model","Fuel efficiency","Sales in thousands","Price in thousands"]].sort_values("Sales in thousands",ascending=False)
# Out:
#                            Model  Fuel efficiency  Sales in thousands  \
# Manufacturer
# Ford           Windstar                      30.0             540.561
# Toyota         Tacoma                        33.0             247.994
# Honda          Passport                      32.0             230.902
# Dodge          Viper                         29.0             227.061
# Jeep           Wrangler                      20.0             157.040
# Chevrolet      Prizm                         45.0             145.519
# Pontiac        Sunfire                       27.0             131.097
# Buick          Regal                         25.0              91.561
# Nissan         Xterra                        30.0              88.094
# Volkswagen     Passat                        27.0              83.721
# Mercury        Villager                      30.0              81.174
# Saturn         SW                            33.0              80.620
# ...

# %%
car.groupby("Manufacturer").min()[["Model","Sales in thousands","Fuel efficiency","Price in thousands"]].sort_values("Fuel efficiency").head(10).sort_values("Sales in thousands",ascending=False)
# Out:
#                           Model  Sales in thousands  Fuel efficiency  \
# Manufacturer
# Jeep          Cherokee                       55.557             17.0
# Ford          Contour                        35.068             16.0
# Nissan        Altima                         27.308             18.0
# Mercury       Cougar                         14.351             18.0
# Lincoln       Continental                    13.798             15.0
# Toyota        4Runner                         9.835             15.0
# Cadillac      Catera                          6.536             15.0
# Lexus         ES300                           3.334             15.0
# Dodge         Avenger                         0.916             15.0
# Mitsubishi    3000GT                          0.110             18.0
#
#               Price in thousands
# Manufacturer
# Jeep                      14.460
# Ford                      12.050
# Nissan                    13.499
# Mercury                   16.240
# ...

# %%
car.groupby("Manufacturer").min()[["Model","Sales in thousands","Fuel efficiency","Price in thousands"]].sort_values("Fuel efficiency").head(10).nlargest(5,'Fuel efficiency')
# Out:
#                           Model  Sales in thousands  Fuel efficiency  \
# Manufacturer
# Nissan        Altima                         27.308             18.0
# Mitsubishi    3000GT                          0.110             18.0
# Mercury       Cougar                         14.351             18.0
# Jeep          Cherokee                       55.557             17.0
# Ford          Contour                        35.068             16.0
#
#               Price in thousands
# Manufacturer
# Nissan                    13.499
# Mitsubishi                13.987
# Mercury                   16.240
# Jeep                      14.460
# Ford                      12.050

# %%
car.groupby("Manufacturer").min()[["Model","Sales in thousands","Fuel efficiency","Price in thousands"]].sort_values("Fuel efficiency").head(10).nsmallest(5,'Fuel efficiency')
# Out:
#                           Model  Sales in thousands  Fuel efficiency  \
# Manufacturer
# Lexus         ES300                           3.334             15.0
# Lincoln       Continental                    13.798             15.0
# Toyota        4Runner                         9.835             15.0
# Dodge         Avenger                         0.916             15.0
# Cadillac      Catera                          6.536             15.0
#
#               Price in thousands
# Manufacturer
# Lexus                     31.505
# Lincoln                   39.080
# Toyota                    11.528
# Dodge                     12.640
# Cadillac                  31.010

# %%
f = pd.DataFrame({'population': [59000000, 65000000, 434000,

                                  434000, 434000, 337000, 11300,

                                  11300, 11300],

                   'GDP': [1937894, 2583560 , 12011, 4520, 12128,

                           17036, 182, 38, 311],

                   'alpha-2': ["IT", "FR", "MT", "MV", "BN",

                               "IS", "NR", "TV", "AI"]},

                  index=["Italy", "France", "Malta",

                         "Maldives", "Brunei", "Iceland",

                         "Nauru", "Tuvalu", "Anguilla"])

# %%
f
# Out:
#           population      GDP alpha-2
# Italy       59000000  1937894      IT
# France      65000000  2583560      FR
# Malta         434000    12011      MT
# Maldives      434000     4520      MV
# Brunei        434000    12128      BN
# Iceland       337000    17036      IS
# Nauru          11300      182      NR
# Tuvalu         11300       38      TV
# Anguilla       11300      311      AI

# %%
f.nlargest(3,'population')
# Out:
#         population      GDP alpha-2
# France    65000000  2583560      FR
# Italy     59000000  1937894      IT
# Malta       434000    12011      MT

# %%
f.nlargest(3,'population',keep='all')
# Out:
#           population      GDP alpha-2
# France      65000000  2583560      FR
# Italy       59000000  1937894      IT
# Malta         434000    12011      MT
# Maldives      434000     4520      MV
# Brunei        434000    12128      BN

# %%
f.nlargest(3,['population','GDP'])
# Out:
#         population      GDP alpha-2
# France    65000000  2583560      FR
# Italy     59000000  1937894      IT
# Brunei      434000    12128      BN

# %%
df.describe()
# Out:
#             Sales
# count    6.000000
# mean   229.500000
# std    100.899455
# min    120.000000
# 25%    143.000000
# 50%    221.500000
# 75%    315.750000
# max    350.000000

# %%
df.describe().transpose()
# Out:
#        count   mean         std    min    25%    50%     75%    max
# Sales    6.0  229.5  100.899455  120.0  143.0  221.5  315.75  350.0

# %%
df.groupby('Company').describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
df.groupby('Company').describe().transpose()
# Out:
# Company              FB        GOOG        MSFT
# Sales count    2.000000    2.000000    2.000000
#       mean   296.500000  160.000000  232.000000
#       std     75.660426   56.568542  152.735065
#       min    243.000000  120.000000  124.000000
#       25%    269.750000  140.000000  178.000000
#       50%    296.500000  160.000000  232.000000
#       75%    323.250000  180.000000  286.000000
#       max    350.000000  200.000000  340.000000

# %%
df.groupby('Company').describe().transpose()[['GOOG','FB']]
# Out:
# Company            GOOG          FB
# Sales count    2.000000    2.000000
#       mean   160.000000  296.500000
#       std     56.568542   75.660426
#       min    120.000000  243.000000
#       25%    140.000000  269.750000
#       50%    160.000000  296.500000
#       75%    180.000000  323.250000
#       max    200.000000  350.000000

# %%
df.groupby('Company').describe().loc[['GOOG','FB'],:]
# Out:
#         Sales
#         count   mean        std    min     25%    50%     75%    max
# Company
# GOOG      2.0  160.0  56.568542  120.0  140.00  160.0  180.00  200.0
# FB        2.0  296.5  75.660426  243.0  269.75  296.5  323.25  350.0

# %% [markdown]
# # Do exercise 1
